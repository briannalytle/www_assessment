# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS


# %matplotlib inline

# %% [markdown]
# # Import Original DataFrame

# %%
www_nlp = pd.read_csv('www_fe.csv', encoding='latin1')

# %%
www_nlp['Page'].unique()
# Out:
# array(['Chrissy Teigen Wore the Pleated-Jean Trend ',
#        'The Best Miami Summer Trends for Under $100 ',
#        "Jennifer Lopez Wore 2019's Biggest Grandma Trend ", ...,
#        'This Cult Beauty Pie Serum Keeps Selling Out ',
#        "11 Cute Summer Outfits You'll Want to Copy ",
#        'Life Lessons Podcast Episode With Molly McNearney '], dtype=object)

# %%
www_nlp.head(1)
# Out:
#        Date                                         Page Title    Age  Gender  \
# 0  20190606  Chrissy Teigen Wore the Pleated-Jean Trend | W...  35-44  female
#
#              Source / Medium  Pageviews  Unique Pageviews  \
# 0  m.facebook.com / referral      35541             31670
#
#                                           Page          Title  \
# 0  Chrissy Teigen Wore the Pleated-Jean Trend   Who What Wear
#
#             Source     Medium  unique_percent  page_wc  source_facebook  \
# 0  m.facebook.com    referral        0.891084        6                1
#
#    source_google  source_yahoo  source_instagram  source_pinterest
# 0              0             0                 0                 0

# %% [markdown]
# # NLP

# %% [markdown]
# CREATE CUSTOM STOP WORDS LIST
#
# DIVIDE BY 6???

# %%
X = www_nlp['Page']
# custom_stop = list(ENGLISH_STOP_WORDS)

# %%
def ngramwords(vecttype, list_ngram, titlelist, list_colors):
    fig, ax = plt.subplots(nrows = 2, ncols = 4, figsize = (20,13))
    plt.subplots_adjust(hspace = 0.6)
    
    ax = ax.ravel()
    for i, vectorizer in enumerate(vecttype):
        vec = vectorizer(ngram_range = list_ngram[i])
        words_df = pd.DataFrame(vec.fit_transform(X).todense(), columns = vec.get_feature_names())
        top_5 = words_df.sum().sort_values(ascending = True).tail(7)
        top_5.plot.bar(ax = ax[i], color = list_colors[i])
        plt.setp(ax[i].get_xticklabels(), ha = "right", rotation = 45)
        
    for i, title in enumerate(titlelist):
        ax[i].set_title(title)

# %%
ngramwords([CountVectorizer, CountVectorizer, CountVectorizer, CountVectorizer, TfidfVectorizer, TfidfVectorizer, TfidfVectorizer, TfidfVectorizer],
          [(1,1), (2,2), (3,3), (4,4), (1,1), (2,2), (3,3), (4,4)],
          ['CountVectorizer - (1,1)', 'CountVectorizer - (2,2)', 'CountVectorizer - (3,3)', 'CountVectorizer - (4,4)',
          'TfidfVectorizer - (1,1)', 'TfidfVectorizer - (2,2)', 'TfidfVectorizer - (3,3)', 'TfidfVectorizer - (4,4)'],
          ['dodgerblue', 'dodgerblue', 'dodgerblue', 'dodgerblue', 'purple', 'purple', 'purple', 'purple'])

# %% [markdown]
# - Most common single terms (with stop words)
# - most common bigrams (no stop words)

# %% [markdown]
# # Stanford Name recognition?
